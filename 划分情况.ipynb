# %% [markdown]
# ## view_of_delft/lidar/ImageSets/

# %% [markdown]
# ### full.txt

# %%
# %matplotlib inline
import matplotlib
# matplotlib.use('TkAgg')  # Set the backend to TkAgg
import matplotlib.pyplot as plt

with open('/workspace/mot/whatch_delft_dataset/view_of_delft/lidar/ImageSets/full.txt', 'r') as file:
    lines = file.readlines()
    frame_numbers = [int(line.strip()) for line in lines]

plt.figure(figsize=(15, 10))  # Set the width and height of the plot
plt.plot(frame_numbers, marker='o', linestyle='-')
plt.xlabel('Index')
plt.ylabel('Frame Number')
plt.title('Frame Numbers')
plt.grid(True)

# Draw horizontal lines at discontinuities
for i in range(1, len(frame_numbers)):
    if abs(frame_numbers[i] - frame_numbers[i - 1]) > 1:
        plt.axhline(y=frame_numbers[i - 1],  color='r', linestyle='--')

plt.show()

# %%
start_indices = []
end_indices = []

with open('/workspace/mot/whatch_delft_dataset/view_of_delft/lidar/ImageSets/full.txt', 'r') as f:
    lines = f.readlines()
    frame_numbers = [int(line.strip()) for line in lines]

start_indices.append(frame_numbers[0])

for i in range(len(frame_numbers) - 1):
    diff = abs(frame_numbers[i + 1] - frame_numbers[i])
    if diff > 1:
        end_indices.append(frame_numbers[i])
        start_indices.append(frame_numbers[i + 1])

end_indices.append(frame_numbers[-1])

assert len(start_indices) == len(end_indices)

total_frames = 0

for i, start_frame in enumerate(start_indices):
    end_frame = end_indices[i]
    num_frames = end_frame - start_frame + 1
    total_frames += num_frames
    print(f"片段:{i},起始帧: {start_frame}, 结束帧: {end_frame}, 该片段帧数: {num_frames}")

print(f"总帧数: {total_frames}")
# Out:
# 片段:0,起始帧: 544, 结束帧: 2531, 该片段帧数: 1988
# 片段:1,起始帧: 3277, 结束帧: 3574, 该片段帧数: 298
# 片段:2,起始帧: 3610, 结束帧: 4047, 该片段帧数: 438
# 片段:3,起始帧: 4049, 结束帧: 4651, 该片段帧数: 603
# 片段:4,起始帧: 6759, 结束帧: 7542, 该片段帧数: 784
# 片段:5,起始帧: 8481, 结束帧: 9095, 该片段帧数: 615
# 片段:6,起始帧: 9518, 结束帧: 9930, 该片段帧数: 413
# 片段:7,起始帧: 0, 结束帧: 543, 该片段帧数: 544
# 片段:8,起始帧: 3575, 结束帧: 3609, 该片段帧数: 35
# 片段:9,起始帧: 4652, 结束帧: 5085, 该片段帧数: 434
# 片段:10,起始帧: 8198, 结束帧: 8480, 该片段帧数: 283
# 片段:11,起始帧: 2532, 结束帧: 3276, 该片段帧数: 745
# 片段:12,起始帧: 6334, 结束帧: 6758, 该片段帧数: 425
# 片段:13,起始帧: 7543, 结束帧: 8197, 该片段帧数: 655
# 片段:14,起始帧: 9096, 结束帧: 9517, 该片段帧数: 422
# 总帧数: 8682

# %% [markdown]
# ### test.txt

# %%
start_indices = []
end_indices = []

with open('/workspace/mot/whatch_delft_dataset/view_of_delft/lidar/ImageSets/test.txt', 'r') as f:
    lines = f.readlines()
    frame_numbers = [int(line.strip()) for line in lines]

start_indices.append(frame_numbers[0])

for i in range(len(frame_numbers) - 1):
    diff = abs(frame_numbers[i + 1] - frame_numbers[i])
    if diff > 1:
        end_indices.append(frame_numbers[i])
        start_indices.append(frame_numbers[i + 1])

end_indices.append(frame_numbers[-1])

assert len(start_indices) == len(end_indices)

total_frames = 0

for i, start_frame in enumerate(start_indices):
    end_frame = end_indices[i]
    num_frames = end_frame - start_frame + 1
    total_frames += num_frames
    print(f"片段:{i},起始帧: {start_frame}, 结束帧: {end_frame}, 该片段帧数: {num_frames}")

print(f"总帧数: {total_frames}")
# Out:
# 片段:0,起始帧: 2532, 结束帧: 3276, 该片段帧数: 745
# 片段:1,起始帧: 6334, 结束帧: 6758, 该片段帧数: 425
# 片段:2,起始帧: 7543, 结束帧: 8197, 该片段帧数: 655
# 片段:3,起始帧: 9096, 结束帧: 9517, 该片段帧数: 422
# 总帧数: 2247

# %% [markdown]
# ### train.txt

# %%
start_indices = []
end_indices = []

with open('/workspace/mot/whatch_delft_dataset/view_of_delft/lidar/ImageSets/train.txt', 'r') as f:
    lines = f.readlines()
    frame_numbers = [int(line.strip()) for line in lines]

start_indices.append(frame_numbers[0])

for i in range(len(frame_numbers) - 1):
    diff = abs(frame_numbers[i + 1] - frame_numbers[i])
    if diff > 1:
        end_indices.append(frame_numbers[i])
        start_indices.append(frame_numbers[i + 1])

end_indices.append(frame_numbers[-1])

assert len(start_indices) == len(end_indices)

total_frames = 0

for i, start_frame in enumerate(start_indices):
    end_frame = end_indices[i]
    num_frames = end_frame - start_frame + 1
    total_frames += num_frames
    print(f"片段:{i},起始帧: {start_frame}, 结束帧: {end_frame}, 该片段帧数: {num_frames}")

print(f"总帧数: {total_frames}")
# Out:
# 片段:0,起始帧: 544, 结束帧: 2531, 该片段帧数: 1988
# 片段:1,起始帧: 3277, 结束帧: 3574, 该片段帧数: 298
# 片段:2,起始帧: 3610, 结束帧: 4047, 该片段帧数: 438
# 片段:3,起始帧: 4049, 结束帧: 4651, 该片段帧数: 603
# 片段:4,起始帧: 6759, 结束帧: 7542, 该片段帧数: 784
# 片段:5,起始帧: 8481, 结束帧: 9095, 该片段帧数: 615
# 片段:6,起始帧: 9518, 结束帧: 9930, 该片段帧数: 413
# 总帧数: 5139

# %% [markdown]
# ### train_val.txt

# %%
start_indices = []
end_indices = []

with open('/workspace/mot/whatch_delft_dataset/view_of_delft/lidar/ImageSets/train_val.txt', 'r') as f:
    lines = f.readlines()
    frame_numbers = [int(line.strip()) for line in lines]

start_indices.append(frame_numbers[0])

for i in range(len(frame_numbers) - 1):
    diff = abs(frame_numbers[i + 1] - frame_numbers[i])
    if diff > 1:
        end_indices.append(frame_numbers[i])
        start_indices.append(frame_numbers[i + 1])

end_indices.append(frame_numbers[-1])

assert len(start_indices) == len(end_indices)

total_frames = 0

for i, start_frame in enumerate(start_indices):
    end_frame = end_indices[i]
    num_frames = end_frame - start_frame + 1
    total_frames += num_frames
    print(f"片段:{i},起始帧: {start_frame}, 结束帧: {end_frame}, 该片段帧数: {num_frames}")

print(f"总帧数: {total_frames}")
# Out:
# 片段:0,起始帧: 544, 结束帧: 2531, 该片段帧数: 1988
# 片段:1,起始帧: 3277, 结束帧: 3574, 该片段帧数: 298
# 片段:2,起始帧: 3610, 结束帧: 4047, 该片段帧数: 438
# 片段:3,起始帧: 4049, 结束帧: 4651, 该片段帧数: 603
# 片段:4,起始帧: 6759, 结束帧: 7542, 该片段帧数: 784
# 片段:5,起始帧: 8481, 结束帧: 9095, 该片段帧数: 615
# 片段:6,起始帧: 9518, 结束帧: 9930, 该片段帧数: 413
# 片段:7,起始帧: 0, 结束帧: 543, 该片段帧数: 544
# 片段:8,起始帧: 3575, 结束帧: 3609, 该片段帧数: 35
# 片段:9,起始帧: 4652, 结束帧: 5085, 该片段帧数: 434
# 片段:10,起始帧: 8198, 结束帧: 8480, 该片段帧数: 283
# 总帧数: 6435

# %% [markdown]
# ### val

# %%
start_indices = []
end_indices = []

with open('/workspace/mot/whatch_delft_dataset/view_of_delft/lidar/ImageSets/val.txt', 'r') as f:
    lines = f.readlines()
    frame_numbers = [int(line.strip()) for line in lines]

start_indices.append(frame_numbers[0])

for i in range(len(frame_numbers) - 1):
    diff = abs(frame_numbers[i + 1] - frame_numbers[i])
    if diff > 1:
        end_indices.append(frame_numbers[i])
        start_indices.append(frame_numbers[i + 1])

end_indices.append(frame_numbers[-1])

assert len(start_indices) == len(end_indices)

total_frames = 0

for i, start_frame in enumerate(start_indices):
    end_frame = end_indices[i]
    num_frames = end_frame - start_frame + 1
    total_frames += num_frames
    print(f"片段:{i},起始帧: {start_frame}, 结束帧: {end_frame}, 该片段帧数: {num_frames}")

print(f"总帧数: {total_frames}")
# Out:
# 片段:0,起始帧: 0, 结束帧: 543, 该片段帧数: 544
# 片段:1,起始帧: 3575, 结束帧: 3609, 该片段帧数: 35
# 片段:2,起始帧: 4652, 结束帧: 5085, 该片段帧数: 434
# 片段:3,起始帧: 8198, 结束帧: 8480, 该片段帧数: 283
# 总帧数: 1296

# %% [markdown]
# ## 总结

# %% [markdown]
# *train(5139)：*
#
# 片段:0,起始帧: 544, 结束帧: 2531, 该片段帧数: 1988
#
# 片段:1,起始帧: 3277, 结束帧: 3574, 该片段帧数: 298
#
# 片段:2,起始帧: 3610, 结束帧: 4047, 该片段帧数: 438
#
# 片段:3,起始帧: 4049, 结束帧: 4651, 该片段帧数: 603
#
# 片段:4,起始帧: 6759, 结束帧: 7542, 该片段帧数: 784
#
# 片段:5,起始帧: 8481, 结束帧: 9095, 该片段帧数: 615
#
# 片段:6,起始帧: 9518, 结束帧: 9930, 该片段帧数: 413
#
# ------------------------------
#
# *val(1296):*
#
# 片段:7,起始帧: 0, 结束帧: 543, 该片段帧数: 544
#
# 片段:8,起始帧: 3575, 结束帧: 3609, 该片段帧数: 35
#
# 片段:9,起始帧: 4652, 结束帧: 5085, 该片段帧数: 434
#
# 片段:10,起始帧: 8198, 结束帧: 8480, 该片段帧数: 283
#
# ------------------------------------------
#
# *test(2247)*:
#
# 片段:11,起始帧: 2532, 结束帧: 3276, 该片段帧数: 745
#
# 片段:12,起始帧: 6334, 结束帧: 6758, 该片段帧数: 425
#
# 片段:13,起始帧: 7543, 结束帧: 8197, 该片段帧数: 655
#
# 片段:14,起始帧: 9096, 结束帧: 9517, 该片段帧数: 422
#
#
#
# 总帧数: 8682
